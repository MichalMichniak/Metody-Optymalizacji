# %%
import metoda_zlotego_podzialu as mzp
import matplotlib.pyplot as plt
import numpy as np
f = lambda x: (x**3 + 1)/(x**2)

print(mzp.golden_ratio_method(f,1,2,0.01,10))
plt.plot(np.linspace(0.01,3,1000000), f(np.linspace(0.01,3,1000000)))
plt.ylim([0,8])
plt.show()
# Out:
# 1.2614195231298895
